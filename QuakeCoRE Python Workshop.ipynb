# %% [markdown]
# # Python for MATLABians
#
# Author: Sung Bae (20221017)

# %% [markdown]
# # Python Fundamentals

# %% [markdown]
# ## Basic syntax

# %%
3+5*4
# Out:
# 23

# %%
2**3 # 2*2*2
# Out:
# 8

# %%
10/3
# Out:
# 3.3333333333333335

# %%
name="Donald Trump"
print(name)
# Out:
# Donald Trump

# %%
weight_lb=244 # 1kg = 2.2 pounds

# %%
weight_kg=weight_lb/2.2

# %% [markdown]
# ## Multiple ways of "print"

# %%
print(name,"weighs",weight_kg,"kg.")
# Out:
# Donald Trump weighs 110.9090909090909 kg.

# %%
print("{} weighs {} kg.".format(name,weight_kg))
# Out:
# Donald Trump weighs 110.9090909090909 kg.

# %%
print(f"{name} weighs {weight_kg} kg.")
# Out:
# Donald Trump weighs 110.9090909090909 kg.

# %%
print(f"{name} weighs {weight_kg:.2f} kg.")
# Out:
# Donald Trump weighs 110.91 kg.

# %% [markdown]
# ## Function

# %%
def lb2kg(lb):
    return lb/2.2

print(lb2kg(244))
# Out:
# 110.9090909090909

# %%
def print_weight(name,lb):
    kg=lb2kg(lb)
    print(f"{name} weighs {kg:.2f} kg or {lb} pounds")

# %%
print_weight(name,weight_lb)
# Out:
# Donald Trump weighs 110.91 kg or 244 pounds

# %%
print_weight("Barack Obama",179.3)
# Out:
# Barack Obama weighs 81.50 kg or 179.3 pounds

# %% [markdown]
# ## List

# %%
a=[3,1,0,2,4]
print(a[0],a[1],a[-1],a[-2])
# Out:
# 3 1 4 2

# %%
print(a[1:3])
# Out:
# [1, 0]

# %%
print(a[:-1]) # last index
# Out:
# [3, 1, 0, 2]

# %%
print(a[:-1:2]) # stride
# Out:
# [3, 0]

# %%
a.sort() #.sort() makes a change to the original list
print(a)
# Out:
# [0, 1, 2, 3, 4]

# %%
a2=[3,1,0,2,4]

print(sorted(a2)) 
print(a2) # If you want to keep the original order, use sorted()
# Out:
# [0, 1, 2, 3, 4]
# [3, 1, 0, 2, 4]

# %%
a.reverse()
print(a) # .reverse() changes the original order
# Out:
# [4, 3, 2, 1, 0]

# %%
b=range(5)
print(b)
# Out:
# range(0, 5)

# %%
print(list(b))
# Out:
# [0, 1, 2, 3, 4]

# %%
b=list(b)

# %%
a==b # a=[4, 3, 2, 1, 0]
# Out:
# False

# %%
a.sort()
a==b
# Out:
# True

# %%
import random
for i in range(5):
    print(i, random.randint(0,10))
# Out:
# 0 9
# 1 8
# 2 3
# 3 3
# 4 1

# %%
c=[]
for i in range(5):
    c.append(random.randint(0,10))
print(c)
# Out:
# [9, 6, 4, 5, 5]

# %%
c.append(10)
print(c)
# Out:
# [9, 6, 4, 5, 5, 10]

# %%
print(c[-1])
# Out:
# 10

# %%
b.extend(c)
print(b)
# Out:
# [0, 1, 2, 3, 4, 9, 6, 4, 5, 5, 10]

# %%
print(2*b)
# Out:
# [0, 1, 2, 3, 4, 9, 6, 4, 5, 5, 10, 0, 1, 2, 3, 4, 9, 6, 4, 5, 5, 10]

# %%
b.remove(0)
print(b)
# Out:
# [1, 2, 3, 4, 9, 6, 4, 5, 5, 10]

# %%
#b.remove(0) # this is intentional
print(b)
# Out:
# [1, 2, 3, 4, 9, 6, 4, 5, 5, 10]

# %%
0 in b
# Out:
# False

# %%
#b.remove(5) # intentional...
#print(b)

# %%
b.insert(2,5) #insert 5 at 2nd index
print(b)
# Out:
# [1, 2, 5, 3, 4, 9, 6, 4, 5, 5, 10]

# %%
5 in b
# Out:
# True

# %% [markdown]
# ## Set

# %% [markdown]
# Set is a container that maintains unique elemements, capable of "membership"-related operations.

# %%
a=[3,2,4,2,4]
a2=set(a)
print(a2)
# Out:
# {2, 3, 4}

# %%
b=[5,3,4,1,1]
b2=set(b)
print(b2)
# Out:
# {1, 3, 4, 5}

# %%
#print(a-b)
print(a2-b2)
# Out:
# {2}

# %%
print(b2-a2)
# Out:
# {1, 5}

# %%
print(a2.intersection(b2))
# Out:
# {3, 4}

# %%
print(a2.union(b2))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Dictionary
# Dictionary is another Python-native data `container`. Like a physical dictionary (or phone directory), we search with a keyword. Dictionary uses curly braces {}

# %%
d={1:10, "key1":20,"key2":"value"}

# %%
d[1]
# Out:
# 10

# %% [markdown]
# A key can be of any type. This is different from list, whose index is 0,1,2....

# %%
d['key1']
# Out:
# 20

# %% [markdown]
# A value can be of any type too. ie. The type of other values in the same dictionary doesn't matter

# %%
d['key2']
# Out:
# 'value'

# %%
d.keys()
# Out:
# dict_keys([1, 'key1', 'key2'])

# %%
d.values()
# Out:
# dict_values([10, 20, 'value'])

# %% [markdown]
# Adding a value can be simply done by assignment. Of course, you need a new key.

# %%
d['key3']=[100,200,300]

# %%
print(d)
# Out:
# {1: 10, 'key1': 20, 'key2': 'value', 'key3': [100, 200, 300]}

# %% [markdown]
# Updating a value can be done by a simple assignment. You just specify the key you want to update.

# %%
d['key2']=3.14

# %%
print(d)
# Out:
# {1: 10, 'key1': 20, 'key2': 3.14, 'key3': [100, 200, 300]}

# %% [markdown]
# Removing from the dictionary is done with `pop()` function.

# %%
d.pop('key3')
# Out:
# [100, 200, 300]

# %%
print(d)
# Out:
# {1: 10, 'key1': 20, 'key2': 3.14}

# %% [markdown]
# ## String

# %%
print(len(name))
# Out:
# 12

# %%
print(name[:6])
# Out:
# Donald

# %%
for i in range(len(name)):
    print(name[i])
# Out:
# D
# o
# n
# a
# l
# d
#
# T
# r
# u
# m
# p

# %%
print(name*3)
# Out:
# Donald TrumpDonald TrumpDonald Trump

# %%
d=name.split(" ")
print(d)
# Out:
# ['Donald', 'Trump']

# %% [markdown]
# ![taumata.png](attachment:taumata.png)
# Welcome to New Zealand
#
# https://en.wikipedia.org/wiki/Taumatawhakatangi%C2%ADhangakoauauotamatea%C2%ADturipukakapikimaunga%C2%ADhoronukupokaiwhen%C2%ADuakitanatahu

# %%
town="Taumatawhakatangihangakoauauotamateaturipukakapikimaungahoronukupokaiwhenuakitanatahu"
print(len(town))
# Out:
# 85

# %%
e=town.split("w") #split when 'w' is found and keep broken pieces in a list
print(e)
# Out:
# ['Taumata', 'hakatangihangakoauauotamateaturipukakapikimaungahoronukupokai', 'henuakitanatahu']

# %%
town2='W'.join(e)
print(town2)
# Out:
# TaumataWhakatangihangakoauauotamateaturipukakapikimaungahoronukupokaiWhenuakitanatahu

# %% [markdown]
# ## If.....else and for-loop (revisited)

# %%
for c in town:
    if c in ['a','e','i','o','u']:
        print(f"{c} is vowel")
    else:
        print(f"{c} is consonant")
# Out:
# T is consonant
# a is vowel
# u is vowel
# m is consonant
# a is vowel
# t is consonant
# a is vowel
# w is consonant
# h is consonant
# a is vowel
# k is consonant
# a is vowel
# t is consonant
# a is vowel
# n is consonant
# g is consonant
# i is vowel
# h is consonant
# a is vowel
# n is consonant
# g is consonant
# a is vowel
# k is consonant
# o is vowel
# a is vowel
# u is vowel
# a is vowel
# u is vowel
# o is vowel
# t is consonant
# a is vowel
# m is consonant
# a is vowel
# t is consonant
# e is vowel
# a is vowel
# t is consonant
# u is vowel
# r is consonant
# i is vowel
# p is consonant
# u is vowel
# k is consonant
# a is vowel
# k is consonant
# a is vowel
# p is consonant
# i is vowel
# k is consonant
# i is vowel
# m is consonant
# a is vowel
# u is vowel
# n is consonant
# g is consonant
# a is vowel
# h is consonant
# o is vowel
# r is consonant
# o is vowel
# n is consonant
# u is vowel
# k is consonant
# u is vowel
# p is consonant
# o is vowel
# k is consonant
# ...

# %%
s="iPhone14"
for c in s:
    if c in ['1','2','3','4','5','6','7','8','9','0']:
        print(f"{c} is a digit")
    elif c in ['a','e','i','o','u']:
        print(f"{c} is a vowel")
    else:
        print(f"{c} is a consonant")
# Out:
# i is a vowel
# P is a consonant
# h is a consonant
# o is a vowel
# n is a consonant
# e is a vowel
# 1 is a digit
# 4 is a digit

# %% [markdown]
# # Challenge

# %% [markdown]
# 1. Write a code that counts the number of vowels, consonants in the town name

# %% [markdown]
# 2. 1 foot is 30.48cm, and 1 inch is 2.54cm in metric respectively. Complete the following function to convert height in foot and inch to centimetres.

# %%
def height_i2m(foot,inch):
    
    # complete here
    height = 0
    return height # cm

print(height_i2m(6,3))
# Out:
# 0

# %% [markdown]
# 3. Based on BMI formula and categories, write a function `compute_bmi()` that behaves as given in the following examples

# %% [markdown]
# When a name, height in foot, inch, and weight in pounds are provided
# ```
# compute_bmi("Spiderman",5,10,174)
# ```
# We want to see an output like this.
# ```
# Spiderman is overweight: bmi 29.07197838097013
# ```
# It will need to (1) convert height and weight in imperial units to metric, (2) compute BMI, and (3) determine which BMI category this person falls into.

# %% [markdown]
# ![bmi-formula.png](attachment:bmi-formula.png)

# %% [markdown]
# ![OIP.jpeg](attachment:OIP.jpeg)

# %%
def compute_bmi(name,height_foot,height_inch,weight_lb):
    
    weight_kg = lb2kg(weight_lb)
    height_m = 2.0 # COMPLETE THIS LINE
    bmi= 20 # COMPLETE THIS LINE
    
    if bmi <= 18.5:
        print(f"{name} is underweight: bmi {bmi}")
    elif bmi > 18.5 and bmi < 24.9:
        print(f"{name} is healthy: bmi {bmi}")
    elif bmi > 25 and bmi < 29.9:
        print(f"{name} is overweight: bmi {bmi}")
    else:
        print(f"{name} is obese: bmi {bmi}")
        
compute_bmi("Spiderman",5,10,174)
compute_bmi("Donald Trump",6,3,244)
compute_bmi("Barack Obama",6,1,179.3)
# Out:
# Spiderman is healthy: bmi 20
# Donald Trump is healthy: bmi 20
# Barack Obama is healthy: bmi 20

# %% [markdown]
# # A little bit of NumPy

# %%
import numpy as np

# %%
#np.loadtxt(fname='AlpineF2K_REL01.csv',delimiter=',') # intentional

# %% [markdown]
# ![AlpineF2K_csv.png](attachment:AlpineF2K_csv.png)

# %%
# https://numpy.org/doc/stable/reference/generated/numpy.loadtxt.html
np.loadtxt(fname='AlpineF2K_REL01.csv',delimiter=',',skiprows=1,usecols=(2,3,9,10,11))
# Out:
# array([[3.97868045e-02, 1.10741701e+01, 3.98288326e-02, 3.99818430e-02,
#         4.04191894e-02],
#        [3.74876745e-02, 9.28794670e+00, 3.75365383e-02, 3.77238673e-02,
#         3.78879327e-02],
#        [2.51209624e-02, 9.20506287e+00, 2.51568716e-02, 2.52517376e-02,
#         2.54902974e-02],
#        ...,
#        [4.76593077e-01, 4.66688499e+01, 4.78316932e-01, 4.87388217e-01,
#         5.24367442e-01],
#        [4.78840560e-01, 5.12621727e+01, 4.81274990e-01, 4.92757576e-01,
#         5.01958223e-01],
#        [5.60877979e-01, 4.58349953e+01, 5.61986187e-01, 5.61562839e-01,
#         5.80792427e-01]])

# %%
ims=np.loadtxt(fname='AlpineF2K_REL01.csv',delimiter=',',skiprows=1,usecols=(2,3,9,10,11))

# %%
ims[0] #index starts at 0
# Out:
# array([ 0.0397868 , 11.07417011,  0.03982883,  0.03998184,  0.04041919])

# %%
ims[1]
# Out:
# array([0.03748767, 9.2879467 , 0.03753654, 0.03772387, 0.03788793])

# %%
ims.shape # columns 0:PGA, 1:PGV, 2:pSA_0.02, 3:pSA_0.05, 4:pSA_0.1
# Out:
# (8296, 5)

# %% [markdown]
# ### Index

# %%
ims[0,2]
# Out:
# 0.03982883263019678

# %%
ims[2,0]
# Out:
# 0.025120962411165237

# %%
ims[0,-1] # -1 is the last index
# Out:
# 0.040419189382671666

# %%
ims[0:2,0] #row index 0,1 (2 NOT included), column index 0.
# Out:
# array([0.0397868 , 0.03748767])

# %%
ims[0:7830,0]
# Out:
# array([0.0397868 , 0.03748767, 0.02512096, ..., 0.0859391 , 0.07151597,
#        0.05916389])

# %%
ims[:,0] # Just : for entire range
# Out:
# array([0.0397868 , 0.03748767, 0.02512096, ..., 0.47659308, 0.47884056,
#        0.56087798])

# %%
ims[:,0].shape
# Out:
# (8296,)

# %%
pga=ims[:,0]

# %%
pga
# Out:
# array([0.0397868 , 0.03748767, 0.02512096, ..., 0.47659308, 0.47884056,
#        0.56087798])

# %%
pga.shape
# Out:
# (8296,)

# %%
pgv=ims[:,1]
psa_0p02=ims[:,2]

# %%
ims[1:10,2:] #Includes 1...9th row, 2nd ...columns
# Out:
# array([[0.03753654, 0.03772387, 0.03788793],
#        [0.02515687, 0.02525174, 0.0254903 ],
#        [0.05651409, 0.05687043, 0.0581395 ],
#        [0.04604895, 0.04618545, 0.0470807 ],
#        [0.03285627, 0.03299543, 0.03313299],
#        [0.02749725, 0.02761631, 0.02814222],
#        [0.02926122, 0.0293457 , 0.02939687],
#        [0.07141352, 0.07193768, 0.07374732],
#        [0.05864219, 0.05918373, 0.0603206 ]])

# %%
ims[:,0:2]
# Out:
# array([[3.97868045e-02, 1.10741701e+01],
#        [3.74876745e-02, 9.28794670e+00],
#        [2.51209624e-02, 9.20506287e+00],
#        ...,
#        [4.76593077e-01, 4.66688499e+01],
#        [4.78840560e-01, 5.12621727e+01],
#        [5.60877979e-01, 4.58349953e+01]])

# %% [markdown]
# ### Axies and functions

# %%
np.max(pga),np.min(pga),np.mean(pga), np.median(pga), np.std(pga)
# Out:
# (1.6890617609024048,
#  0.005810029339045286,
#  0.0820086285950263,
#  0.04298967868089676,
#  0.13570291830357967)

# %%
np.max(ims,axis=0) #which are max of PGA, PGV, pSA_0.02, pSA_0.05, pSA_0.1 respectivly
# Out:
# array([  1.68906176, 156.23571777,   1.69837235,   1.73099313,
#          1.79483771])

# %% [markdown]
# **Note** for-loop in Python is slow. If you are concerned of the execution speed, see if it can be done with a numpy function.

# %%
#eg. Use np.max(pga) instead of below
max_pga=-9999
for v in pga:
    if v >= max_pga:
        max_pga = v
print(max_pga)
# Out:
# 1.6890617609024048

# %% [markdown]
# ### Transposing, Sorting and concatenating

# %%
Y= np.array([
    [1,2],
    [3,4],
    [5,6]
])
print(Y)
print(Y.T) #or Y.transpose()
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[1 3 5]
#  [2 4 6]]

# %%
Y.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
Y.reshape(6,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %%
Z=np.array([
    [7,1,4],
    [8,6,5],
    [1,2,3]
])
np.sort(Z)
# Out:
# array([[1, 4, 7],
#        [5, 6, 8],
#        [1, 2, 3]])

# %%
print(np.sort(Z,axis=0))
print(np.sort(Z,axis=1))
print(np.sort(Z,axis=None))
# Out:
# [[1 1 3]
#  [7 2 4]
#  [8 6 5]]
# [[1 4 7]
#  [5 6 8]
#  [1 2 3]]
# [1 1 2 3 4 5 6 7 8]

# %%
V=np.array([
    [4,8],
    [6,1]
])
W=np.array([
    [3,5],
    [7,2]
])
np.vstack([V,W])
# Out:
# array([[4, 8],
#        [6, 1],
#        [3, 5],
#        [7, 2]])

# %%
np.hstack([V,W])
# Out:
# array([[4, 8, 3, 5],
#        [6, 1, 7, 2]])

# %%
np.concatenate([V,W],axis=0)
# Out:
# array([[4, 8],
#        [6, 1],
#        [3, 5],
#        [7, 2]])

# %%
np.concatenate([V,W],axis=1)
# Out:
# array([[4, 8, 3, 5],
#        [6, 1, 7, 2]])

# %%
np.concatenate([V,W],axis=None)
# Out:
# array([4, 8, 6, 1, 3, 5, 7, 2])

# %% [markdown]
# ### Calculation with array

# %%
10*V
# Out:
# array([[40, 80],
#        [60, 10]])

# %%
V+W
# Out:
# array([[ 7, 13],
#        [13,  3]])

# %%
V*W
# Out:
# array([[12, 40],
#        [42,  2]])

# %% [markdown]
# ### Masking and Filtering

# %%
X=pga[:20]
print(X)
# Out:
# [0.0397868  0.03748767 0.02512096 0.05640869 0.04596645 0.03281318
#  0.02745536 0.02923263 0.07125691 0.05848226 0.04785532 0.03928876
#  0.03632672 0.02676102 0.03593028 0.02921537 0.18014404 0.10115183
#  0.09172485 0.13655233]

# %%
print(np.mean(X))
mask = X > np.mean(X)
print(mask)
# Out:
# 0.05744807254523039
# [False False False False False False False False  True  True False False
#  False False False False  True  True  True  True]

# %%
X[mask]
# Out:
# array([0.07125691, 0.05848226, 0.18014404, 0.10115183, 0.09172485,
#        0.13655233])

# %%
X[X > np.mean(X)]
# Out:
# array([0.07125691, 0.05848226, 0.18014404, 0.10115183, 0.09172485,
#        0.13655233])

# %% [markdown]
# # Challenge

# %% [markdown]
# Load columns containing CAV, AI and MMI from the same CSV file, and add them to the ims array

# %% [markdown]
# # A little bit of Matplotlib
# https://matplotlib.org/stable/gallery/index.html

# %%
import matplotlib.pyplot as plt
x=np.arange(0, 10, 0.5) # [0, 0.5, 1.0, ... 9.5]
y= x * x
fig, ax = plt.subplots()
ax.plot(x,y,'o')
ax.set(xlabel="x",ylabel="y", title='y=x**2')
ax.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
x=np.arange(0, 2*np.pi, 0.1) # [0, 0.5, 1.0, ... 9.5]
y=np.sin(x)

fig, ax = plt.subplots()
ax.plot(x,y,'o') # try '-' instead
ax.set(xlabel="x",ylabel="y", title='y=sin(x)')
ax.grid()
plt.show()

# %% [markdown]
# ## Normal distribution

# %%
import scipy.stats as stats
import pylab as pl

h = sorted([186, 176, 158, 180, 186, 168, 168, 164, 178, 170, 189, 195, 172,
     187, 180, 186, 185, 168, 179, 178, 183, 179, 170, 175, 186, 159,
     161, 178, 175, 185, 175, 162, 173, 172, 177, 175, 172, 177, 180])

fit = stats.norm.pdf(sorted(h), np.mean(h), np.std(h))  

pl.plot(sorted(h),fit,'g-*')

pl.hist(h,density=True,facecolor='y')      #use this to draw histogram of your data

pl.show()

# %%
sorted_pgv=sorted(pgv) # what happens if not sorted?
fit = stats.norm.pdf(sorted_pgv, np.mean(pgv), np.std(pgv)) 
pl.plot(sorted_pgv,fit,'-')

pl.hist(sorted_pgv,50,density=True)
pl.show()

# %% [markdown]
# ## Subplots

# %%
fig = plt.figure(figsize=(10.0, 3.0))
axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)


axes1.set_xlabel('station id')
axes1.set_ylabel('PGA')
axes1.plot(pga,'g', alpha=0.5)

axes2.set_xlabel('station id')
axes2.set_ylabel('PGV')
axes2.plot(pgv,'b', alpha=0.5)

axes3.set_xlabel('station id')
axes3.set_ylabel('pSA_0.02')
axes3.plot(psa_0p02,'r', alpha=0.5)

fig.tight_layout()

plt.savefig('IMS.png')
plt.show()

# %% [markdown]
# # Pandas
# Better ways handling CSV files and DataFrames.
#
# Let's start with opening a CSV file.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
import pandas as pd
pd.read_csv("AlpineF2K_REL01.csv",index_col=0)
# Out:
#         component       PGA        PGV       CAV          AI      Ds575  \
# station
# 0200000      geom  0.039787  11.074170  0.271182    4.686345  13.040230
# 0200001      geom  0.037488   9.287947  0.239492    3.331137  13.964927
# 0200002      geom  0.025121   9.205063  0.218508    2.579750  15.175234
# 0200003      geom  0.056409  12.831129  0.315140    6.860039  11.949393
# 0200004      geom  0.045966  11.200073  0.280166    5.005803  12.834528
# ...           ...       ...        ...       ...         ...        ...
# WSFC         geom  0.092635  45.002934  1.328110   56.162079  27.839721
# WTMC         geom  0.024571  13.212903  0.195348    1.995125  14.995859
# WVAS         geom  0.476593  46.668850  2.161510  426.839276   8.782835
# WVZ          geom  0.478841  51.262173  2.169289  464.965127   8.133795
# WVZS         geom  0.560878  45.834995  2.144804  467.738633   7.814998
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...  pSA_1.25   pSA_1.5  \
# ...

# %%
ims_df=pd.read_csv("AlpineF2K_REL01.csv",index_col=0)

# %%
ims_df.dtypes
# Out:
# component     object
# PGA          float64
# PGV          float64
# CAV          float64
# AI           float64
# Ds575        float64
# Ds595        float64
# MMI          float64
# pSA_0.01     float64
# pSA_0.02     float64
# pSA_0.03     float64
# pSA_0.04     float64
# pSA_0.05     float64
# pSA_0.075    float64
# pSA_0.1      float64
# pSA_0.12     float64
# pSA_0.15     float64
# pSA_0.17     float64
# pSA_0.2      float64
# pSA_0.25     float64
# pSA_0.3      float64
# pSA_0.4      float64
# pSA_0.5      float64
# pSA_0.6      float64
# pSA_0.7      float64
# pSA_0.75     float64
# pSA_0.8      float64
# pSA_0.9      float64
# pSA_1.0      float64
# pSA_1.25     float64
# pSA_1.5      float64
# pSA_2.0      float64
# pSA_2.5      float64
# pSA_3.0      float64
# pSA_4.0      float64
# pSA_5.0      float64
# pSA_6.0      float64
# pSA_7.5      float64
# pSA_10.0     float64
# dtype: object

# %%
ims_df.describe() # gives you a summary of dataframe
# Out:
#                PGA          PGV          CAV           AI        Ds575  \
# count  8296.000000  8296.000000  8296.000000  8296.000000  8296.000000
# mean      0.082009    17.115630     0.726606    51.483725    30.747394
# std       0.135711    16.224219     0.659339   160.448151    14.275756
# min       0.005810     2.592690     0.081726     0.236292     4.620049
# 25%       0.023021     7.599679     0.313870     3.184431    18.297637
# 50%       0.042990    11.146060     0.502971     8.955218    31.066802
# 75%       0.075055    19.735827     0.911677    29.164917    42.264434
# max       1.689062   156.235718     4.784420  2783.580524    61.850506
#
#              Ds595          MMI     pSA_0.01     pSA_0.02     pSA_0.03  ...  \
# count  8296.000000  8296.000000  8296.000000  8296.000000  8296.000000  ...
# mean     48.806378     6.387982     0.082212     0.082952     0.084914  ...
# std      21.381853     0.968831     0.136269     0.138366     0.143994  ...
# ...

# %%
ims_df.head()
# Out:
#         component       PGA        PGV       CAV        AI      Ds575  \
# station
# 0200000      geom  0.039787  11.074170  0.271182  4.686345  13.040230
# 0200001      geom  0.037488   9.287947  0.239492  3.331137  13.964927
# 0200002      geom  0.025121   9.205063  0.218508  2.579750  15.175234
# 0200003      geom  0.056409  12.831129  0.315140  6.860039  11.949393
# 0200004      geom  0.045966  11.200073  0.280166  5.005803  12.834528
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...  pSA_1.25   pSA_1.5  \
# station                                           ...
# 0200000  18.752863  6.189503  0.039829  0.039982  ...  0.055332  0.061121
# 0200001  21.036159  5.948425  0.037537  0.037724  ...  0.054967  0.046396
# 0200002  22.725334  5.936216  0.025157  0.025252  ...  0.053523  0.042814
# 0200003  17.127386  6.391167  0.056514  0.056870  ...  0.065148  0.082748
# 0200004  19.026017  6.204769  0.046049  0.046185  ...  0.067499  0.047961
#
# ...

# %%
ims_df.index
# Out:
# Index(['0200000', '0200001', '0200002', '0200003', '0200004', '0200005',
#        '0200006', '0200007', '0200008', '0200009',
#        ...
#        'WHFS', 'WHZ', 'WIGC', 'WKZ', 'WNPS', 'WSFC', 'WTMC', 'WVAS', 'WVZ',
#        'WVZS'],
#       dtype='object', name='station', length=8296)

# %%
ims_df.columns
# Out:
# Index(['component', 'PGA', 'PGV', 'CAV', 'AI', 'Ds575', 'Ds595', 'MMI',
#        'pSA_0.01', 'pSA_0.02', 'pSA_0.03', 'pSA_0.04', 'pSA_0.05', 'pSA_0.075',
#        'pSA_0.1', 'pSA_0.12', 'pSA_0.15', 'pSA_0.17', 'pSA_0.2', 'pSA_0.25',
#        'pSA_0.3', 'pSA_0.4', 'pSA_0.5', 'pSA_0.6', 'pSA_0.7', 'pSA_0.75',
#        'pSA_0.8', 'pSA_0.9', 'pSA_1.0', 'pSA_1.25', 'pSA_1.5', 'pSA_2.0',
#        'pSA_2.5', 'pSA_3.0', 'pSA_4.0', 'pSA_5.0', 'pSA_6.0', 'pSA_7.5',
#        'pSA_10.0'],
#       dtype='object')

# %% [markdown]
# ### Selection of  row(s)

# %%
ims_df.loc['0200000']
# Out:
# component         geom
# PGA           0.039787
# PGV           11.07417
# CAV           0.271182
# AI            4.686345
# Ds575         13.04023
# Ds595        18.752863
# MMI           6.189503
# pSA_0.01      0.039829
# pSA_0.02      0.039982
# pSA_0.03      0.040419
# pSA_0.04      0.042019
# pSA_0.05      0.045294
# pSA_0.075     0.048907
# pSA_0.1       0.059321
# pSA_0.12      0.064482
# pSA_0.15      0.068976
# pSA_0.17      0.074535
# pSA_0.2       0.095346
# pSA_0.25      0.090219
# pSA_0.3       0.079091
# pSA_0.4       0.110731
# pSA_0.5       0.090921
# pSA_0.6       0.080676
# pSA_0.7       0.067671
# pSA_0.75      0.086616
# pSA_0.8       0.084286
# pSA_0.9       0.065784
# pSA_1.0       0.053295
# pSA_1.25      0.055332
# pSA_1.5       0.061121
# pSA_2.0       0.047908
# pSA_2.5       0.051498
# pSA_3.0       0.042514
# pSA_4.0       0.052528
# pSA_5.0       0.044689
# pSA_6.0        0.03046
# pSA_7.5       0.015595
# pSA_10.0      0.007536
# ...

# %%
ims_df.iloc[0]

# %% [markdown]
# .iloc is handy when you are processing rows via for-loop. Also you can access the last row without knowing actual index.

# %%
ims_df.iloc[-1]

# %%
ims_df.loc['0200000':'0200002']
# Out:
#         component       PGA        PGV       CAV        AI      Ds575  \
# station
# 0200000      geom  0.039787  11.074170  0.271182  4.686345  13.040230
# 0200001      geom  0.037488   9.287947  0.239492  3.331137  13.964927
# 0200002      geom  0.025121   9.205063  0.218508  2.579750  15.175234
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...  pSA_1.25   pSA_1.5  \
# station                                           ...
# 0200000  18.752863  6.189503  0.039829  0.039982  ...  0.055332  0.061121
# 0200001  21.036159  5.948425  0.037537  0.037724  ...  0.054967  0.046396
# 0200002  22.725334  5.936216  0.025157  0.025252  ...  0.053523  0.042814
#
#           pSA_2.0   pSA_2.5   pSA_3.0   pSA_4.0   pSA_5.0   pSA_6.0   pSA_7.5  \
# station
# 0200000  0.047908  0.051498  0.042514  0.052528  0.044689  0.030460  0.015595
# 0200001  0.034988  0.031535  0.032078  0.032617  0.037325  0.028486  0.015318
# ...

# %%
ims_df.iloc[0:3]
# Out:
#         component       PGA        PGV       CAV        AI      Ds575  \
# station
# 0200000      geom  0.039787  11.074170  0.271182  4.686345  13.040230
# 0200001      geom  0.037488   9.287947  0.239492  3.331137  13.964927
# 0200002      geom  0.025121   9.205063  0.218508  2.579750  15.175234
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...  pSA_1.25   pSA_1.5  \
# station                                           ...
# 0200000  18.752863  6.189503  0.039829  0.039982  ...  0.055332  0.061121
# 0200001  21.036159  5.948425  0.037537  0.037724  ...  0.054967  0.046396
# 0200002  22.725334  5.936216  0.025157  0.025252  ...  0.053523  0.042814
#
#           pSA_2.0   pSA_2.5   pSA_3.0   pSA_4.0   pSA_5.0   pSA_6.0   pSA_7.5  \
# station
# 0200000  0.047908  0.051498  0.042514  0.052528  0.044689  0.030460  0.015595
# 0200001  0.034988  0.031535  0.032078  0.032617  0.037325  0.028486  0.015318
# ...

# %% [markdown]
# ### Selection of column(s)

# %%
ims_df['PGA'] #or ims_df.PGA
# Out:
# station
# 0200000    0.039787
# 0200001    0.037488
# 0200002    0.025121
# 0200003    0.056409
# 0200004    0.045966
#              ...
# WSFC       0.092635
# WTMC       0.024571
# WVAS       0.476593
# WVZ        0.478841
# WVZS       0.560878
# Name: PGA, Length: 8296, dtype: float64

# %%
ims_df[['PGA','PGV','pSA_0.02']]
# Out:
#               PGA        PGV  pSA_0.02
# station
# 0200000  0.039787  11.074170  0.039982
# 0200001  0.037488   9.287947  0.037724
# 0200002  0.025121   9.205063  0.025252
# 0200003  0.056409  12.831129  0.056870
# 0200004  0.045966  11.200073  0.046185
# ...           ...        ...       ...
# WSFC     0.092635  45.002934  0.093068
# WTMC     0.024571  13.212903  0.024647
# WVAS     0.476593  46.668850  0.487388
# WVZ      0.478841  51.262173  0.492758
# WVZS     0.560878  45.834995  0.561563
#
# [8296 rows x 3 columns]

# %%
ims_df.loc['0200000','PGA'] # or
# Out:
# 0.0397868044674396

# %%
ims_df.loc['0200000']['PGA'] # or
# Out:
# 0.0397868044674396

# %%
ims_df.loc['0200000'].PGA
# Out:
# 0.0397868044674396

# %% [markdown]
# ### Selection by condition

# %%
ims_df.loc[ims_df.PGA > 0.6]
# Out:
#         component       PGA         PGV       CAV           AI     Ds575  \
# station
# 0200036      geom  0.673049   73.397003  1.844933   472.289010  7.464583
# 0200047      geom  0.653440   77.848686  2.640311   714.456282  7.654430
# 020005a      geom  0.792677   90.581932  3.202621  1012.846876  7.861135
# 020006d      geom  0.768916   91.133835  2.809280   707.626135  7.320656
# 0200080      geom  0.884249  102.481667  4.079025  1551.776379  7.838868
# ...           ...       ...         ...       ...          ...       ...
# HDWS         geom  0.620118   98.792511  3.449568   788.426131  6.564347
# MSZ          geom  0.621806   74.842049  3.522661   840.898094  9.773589
# MSZS         geom  0.713562   80.922577  3.688747   951.928209  9.160690
# WHAS         geom  0.737007   81.774765  3.176969   760.862474  8.322692
# WHFS         geom  0.781484   72.436821  3.142449   760.625986  8.919956
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...  pSA_1.25   pSA_1.5  \
# ...

# %%
np.mean(ims_df.PGA) # OR
# Out:
# 0.0820086285950263

# %%
ims_df.PGA.mean()
# Out:
# 0.0820086285950263

# %%
ims_df.loc[ims_df.PGA >  ims_df.PGA.mean()]
# Out:
#         component       PGA        PGV       CAV          AI      Ds575  \
# station
# 0200010      geom  0.180144  29.908695  0.590998   33.065108   8.553210
# 0200011      geom  0.101152  28.107777  0.502943   20.248559   9.971173
# 0200012      geom  0.091725  18.696659  0.435426   14.267866  10.794906
# 0200013      geom  0.136552  21.137659  0.669431   34.577348  11.106698
# 020001b      geom  0.270792  60.213898  0.908440   93.207053   7.129299
# ...           ...       ...        ...       ...         ...        ...
# WNPS         geom  0.095917  15.905576  1.228340   42.255885  36.430006
# WSFC         geom  0.092635  45.002934  1.328110   56.162079  27.839721
# WVAS         geom  0.476593  46.668850  2.161510  426.839276   8.782835
# WVZ          geom  0.478841  51.262173  2.169289  464.965127   8.133795
# WVZS         geom  0.560878  45.834995  2.144804  467.738633   7.814998
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...  pSA_1.25   pSA_1.5  \
# ...

# %% [markdown]
# ### Convert to Numpy Array

# %%
ims_df.to_numpy()
# Out:
# array([['geom', 0.0397868044674396, 11.074170112609863, ...,
#         0.0304597191087909, 0.015594611937667, 0.0075363317663175],
#        ['geom', 0.0374876745045185, 9.287946701049805, ...,
#         0.0284861962250069, 0.0153178385382891, 0.0056216145607399],
#        ['geom', 0.0251209624111652, 9.205062866210938, ...,
#         0.0279476107298087, 0.0157900344210042, 0.0053756841899347],
#        ...,
#        ['geom', 0.4765930771827698, 46.66884994506836, ...,
#         0.0313115803361904, 0.0316743195072624, 0.0269572138022188],
#        ['geom', 0.478840559720993, 51.26217269897461, ...,
#         0.035928806425509, 0.0321379540203976, 0.0270127537698418],
#        ['geom', 0.5608779788017273, 45.83499526977539, ...,
#         0.0319952671989906, 0.0313410406399801, 0.0277032879566209]],
#       dtype=object)

# %%
ims_df[['PGA','PGV','pSA_0.02','pSA_0.05','pSA_0.1']].to_numpy() #same as ims created by np.loadtxt()
# Out:
# array([[3.97868045e-02, 1.10741701e+01, 3.99818430e-02, 4.52944498e-02,
#         5.93209997e-02],
#        [3.74876745e-02, 9.28794670e+00, 3.77238673e-02, 3.90944035e-02,
#         5.26982666e-02],
#        [2.51209624e-02, 9.20506287e+00, 2.52517376e-02, 2.81945523e-02,
#         3.53352652e-02],
#        ...,
#        [4.76593077e-01, 4.66688499e+01, 4.87388217e-01, 6.59760240e-01,
#         1.07391445e+00],
#        [4.78840560e-01, 5.12621727e+01, 4.92757576e-01, 6.45322762e-01,
#         1.39028185e+00],
#        [5.60877979e-01, 4.58349953e+01, 5.61562839e-01, 6.88866998e-01,
#         1.46989618e+00]])

# %% [markdown]
# ### Adding columns

# %% [markdown]
# PGA is in "g" while PGV is in cm/s. Let's convert PGA to cm/s^2 by muptiplying 981cm/s^2

# %%
ims_df['PGA']*981
# Out:
# station
# 0200000     39.030855
# 0200001     36.775409
# 0200002     24.643664
# 0200003     55.336927
# 0200004     45.093088
#               ...
# WSFC        90.874648
# WTMC        24.103741
# WVAS       467.537809
# WVZ        469.742589
# WVZS       550.221297
# Name: PGA, Length: 8296, dtype: float64

# %%
ims_df['PGA_cm']=ims_df['PGA']*981

# %%
ims_df
# Out:
#         component       PGA        PGV       CAV          AI      Ds575  \
# station
# 0200000      geom  0.039787  11.074170  0.271182    4.686345  13.040230
# 0200001      geom  0.037488   9.287947  0.239492    3.331137  13.964927
# 0200002      geom  0.025121   9.205063  0.218508    2.579750  15.175234
# 0200003      geom  0.056409  12.831129  0.315140    6.860039  11.949393
# 0200004      geom  0.045966  11.200073  0.280166    5.005803  12.834528
# ...           ...       ...        ...       ...         ...        ...
# WSFC         geom  0.092635  45.002934  1.328110   56.162079  27.839721
# WTMC         geom  0.024571  13.212903  0.195348    1.995125  14.995859
# WVAS         geom  0.476593  46.668850  2.161510  426.839276   8.782835
# WVZ          geom  0.478841  51.262173  2.169289  464.965127   8.133795
# WVZS         geom  0.560878  45.834995  2.144804  467.738633   7.814998
#
#              Ds595       MMI  pSA_0.01  pSA_0.02  ...   pSA_1.5   pSA_2.0  \
# ...

# %% [markdown]
# ### Export to CSV

# %% [markdown]
# Let's export ims_df to a CSV file, but we want PGA and PGA_cm columns only.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

# %%
ims_df.to_csv('ims2.csv',columns=['PGA','PGA_cm'])

# %% [markdown]
# # Explore 3rd libraries: [Example] GeoPandas
#
# Techniques covered so far should be (hopefully!) adequate to explore other Python libraries. While we do most plottings using GMT, I stumbled upon GeoPandas which I wanted to try out and see.

# %% [markdown]
# ![LINZ.png](attachment:LINZ.png)
#
# I did some research and found that we need .shp file for New Zealand, which I downloaded from https://data.linz.govt.nz/data/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %% [markdown]
# The file `real_nz_stations.ll` supplied contains the location of all stations installed in New Zealand.

# %%
#stations = pd.read_csv("real_nz_stations.ll",sep=' ',header=None,index_col=2,names=['lon','lat','station'])
stations = pd.read_csv("non_uniform_whole_nz_with_real_stations-hh400_v20p3_land.ll",sep=' ',header=None,index_col=2,names=['lon','lat','station'])

# %%
stations
# Out:
#                 lon        lat
# station
# HNPS     176.880100 -39.671000
# TRMS     175.991000 -40.671300
# NSPS     176.915900 -39.489600
# MWZ      177.527800 -38.334000
# NCDS     176.876100 -39.498400
# ...             ...        ...
# 4201628  178.289215 -38.370208
# 4201629  178.318050 -37.887453
# 420162a  178.323742 -37.891944
# 420162b  178.318050 -37.896436
# 420162c  178.312358 -37.891944
#
# [25948 rows x 2 columns]

# %%
crs={'init':'epsg:4326'}

# %%
geometry=[Point(xy) for xy in zip(stations["lon"], stations["lat"])]

# %%
geodata=gpd.GeoDataFrame(stations,crs=crs, geometry=geometry)
print(geodata)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ringo39/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#                 lon        lat                     geometry
# station
# HNPS     176.880100 -39.671000  POINT (176.88010 -39.67100)
# TRMS     175.991000 -40.671300  POINT (175.99100 -40.67130)
# NSPS     176.915900 -39.489600  POINT (176.91590 -39.48960)
# MWZ      177.527800 -38.334000  POINT (177.52780 -38.33400)
# NCDS     176.876100 -39.498400  POINT (176.87610 -39.49840)
# ...             ...        ...                          ...
# 4201628  178.289215 -38.370208  POINT (178.28921 -38.37021)
# 4201629  178.318050 -37.887453  POINT (178.31805 -37.88745)
# ...

# %%
geodata.plot()
# Out:
# <AxesSubplot:>

# %%
nz_shapefile = gpd.read_file('nz_coastlines/nz-coastlines-topo-150k.shp')

# %%
fig, ax = plt.subplots(figsize=(7,7))

nz_shapefile.plot(ax=ax, facecolor='Grey', edgecolor='k',alpha=1,linewidth=1,cmap="cividis")

#You can use different 'cmaps' such as jet, plasma,magma, infereno,cividis, binary...(I simply chose cividis)

geodata.plot(color='red', markersize=5); #Add argument ax=ax
fig.suptitle('Location of stations', fontsize=12)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium')
# Out:
# Text(122.42368409056492, 0.5, 'Latitude')

# %% [markdown]
# ## Challenge: PGV data on the map

# %% [markdown]
# `ims_df` contains PGV, but to plot them on the map, we need the (lon,lat) of each station. That infomation is available in `stations`. How can we put things together?
#
# More about join: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html

# %%
pgv_data=ims_df.join(stations,how='right')[['lon','lat','PGV']] #joining 2 dataframes on index "station" name
print(pgv_data)
# Out:
#                 lon        lat  PGV
# station
# HNPS     176.880100 -39.671000  NaN
# TRMS     175.991000 -40.671300  NaN
# NSPS     176.915900 -39.489600  NaN
# MWZ      177.527800 -38.334000  NaN
# NCDS     176.876100 -39.498400  NaN
# ...             ...        ...  ...
# 4201628  178.289215 -38.370208  NaN
# 4201629  178.318050 -37.887453  NaN
# 420162a  178.323742 -37.891944  NaN
# 420162b  178.318050 -37.896436  NaN
# 420162c  178.312358 -37.891944  NaN
#
# [25948 rows x 3 columns]

# %%
pgv_data=pgv_data.fillna(0)
print(pgv_data)
# Out:
#                 lon        lat  PGV
# station
# HNPS     176.880100 -39.671000  0.0
# TRMS     175.991000 -40.671300  0.0
# NSPS     176.915900 -39.489600  0.0
# MWZ      177.527800 -38.334000  0.0
# NCDS     176.876100 -39.498400  0.0
# ...             ...        ...  ...
# 4201628  178.289215 -38.370208  0.0
# 4201629  178.318050 -37.887453  0.0
# 420162a  178.323742 -37.891944  0.0
# 420162b  178.318050 -37.896436  0.0
# 420162c  178.312358 -37.891944  0.0
#
# [25948 rows x 3 columns]

# %%
pgv_data.loc[pgv_data.PGV>0]
# Out:
#                 lon        lat        PGV
# station
# HSES     172.830500 -42.523200  10.999412
# HALS     172.569500 -43.590900   9.726518
# GOVS     172.635700 -43.652400   5.203282
# DHSS     172.727200 -43.630300   5.797308
# WBCS     171.599800 -41.755700  11.099491
# ...             ...        ...        ...
# 42003bd  172.732693 -43.630779   5.787543
# 4200422  173.180209 -42.530174  10.651510
# 4200423  173.186304 -42.534665  10.545277
# 4200424  173.180209 -42.539157  10.965903
# 4200425  173.174113 -42.534665  10.549625
#
# [8296 rows x 3 columns]

# %%
geometry=[Point(xy) for xy in zip(pgv_data["lon"], pgv_data["lat"])]

# %%
geodata2=gpd.GeoDataFrame(pgv_data,crs=crs, geometry=geometry)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ringo39/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
geodata2.to_file("pgv_all.shp")

# %%
fig, ax = plt.subplots(figsize=(10,10))

nz_shapefile.plot(ax=ax, facecolor='Grey', edgecolor='k',alpha=1,linewidth=1)


#You can use different 'cmaps' such as jet, plasma,magma, infereno,cividis, binary...(I simply chose cividis)

geodata2.plot('PGV',ax=ax, legend=True, markersize=1, cmap="jet");

fig.suptitle('PGV at stations', fontsize=12)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium')
# Out:
# Text(152.80925747531737, 0.5, 'Latitude')

# %%
pgv_array=pgv_data[['lon','lat','PGV']].to_numpy()

# %%
from matplotlib.tri import Triangulation, LinearTriInterpolator

# %%
triFn=Triangulation(pgv_array[:,0],pgv_array[:,1])
linTriFn=LinearTriInterpolator(triFn,pgv_array[:,2])
rasterRes = 0.01
xCoords=np.arange(pgv_array[:,0].min(),pgv_array[:,0].max()+rasterRes,rasterRes)
yCoords=np.arange(pgv_array[:,1].min(),pgv_array[:,1].max()+rasterRes,rasterRes)
print(xCoords.shape)
print(yCoords.shape)
zCoords=np.zeros([yCoords.shape[0],xCoords.shape[0]])
#loop among each cell in the raster extension
for indexX, x in np.ndenumerate(xCoords):
    for indexY, y in np.ndenumerate(yCoords):
        tempZ = linTriFn(x,y)
        #filtering masked values
        if tempZ == tempZ:
            zCoords[indexY,indexX]=tempZ
        else:
            zCoords[indexY,indexX]=np.nan

#preliminary representation of the interpolated values
plt.imshow(zCoords)
# Out:
# (1210,)
# (1286,)

# %%
from rasterio.transform import Affine
transform = Affine.translation(xCoords[0] - rasterRes/2, yCoords[0] - rasterRes/2) * Affine.scale(rasterRes, rasterRes)

# %%
transform
# Out:
# Affine(0.01, 0.0, 166.45694,
#        0.0, 0.01, -47.28065)

# %%
from rasterio.crs import CRS
import rasterio
rasterCrs = CRS.from_epsg(4326)
rasterCrs.data
# Out:
# {'init': 'epsg:4326'}

# %%
triInterpRaster = rasterio.open('triangleInterpolation.tif',
                                'w',
                                driver='GTiff',
                                height=zCoords.shape[0],
                                width=zCoords.shape[1],
                                count=1,
                                dtype=zCoords.dtype,
                                #crs='+proj=latlong',
                                crs=rasterCrs.data,
                                transform=transform,
                                )
triInterpRaster.write(zCoords,1)
triInterpRaster.close()

# %% [markdown]
# https://hatarilabs.com/ih-en/geospatial-triangular-interpolation-with-python-scipy-geopandas-and-rasterio-tutorial

# %% [markdown]
# # Advanced materials

# %% [markdown]
# - Official Python tutorial: https://docs.python.org/3/tutorial/index.html
# - Pandas: https://www.stackvidhya.com/select-columns-from-pandas-dataframe/
# - ObsPy https://github.com/roseseismo/roses2020/blob/master/unit01/Obspy_Tutorial_Full_Notebook.ipynb (Youtube: https://youtu.be/PRECSp2bb20)
#
# - pyGMT: https://github.com/roseseismo/roses2020/blob/master/unit08/roses_pygmt_lecture.ipynb (Youtube: https://youtu.be/SSIGJEe0BIk )
